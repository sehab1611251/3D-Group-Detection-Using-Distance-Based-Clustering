# %% [markdown]
# <a href="https://colab.research.google.com/github/sehab1611251/3D-Group-Detection-Using-Distance-Based-Clustering/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **DBSCAN clustering performance on JRDB Ground Truth 3D Bounding Boxes**

# %%
import json
from collections import defaultdict, Counter

# Path to the input ground truth JSON file
json_path = "/content/clark-center-2019-02-28_0.json"

# Output file path for processed GT.txt
gt_output_path = "/content/GT.txt"  # Format: <frame>, <group_id>, <x>, <y>, <z>, <length>, <width>, <height>, <group_label>

# Initialize containers
ground_truth_detections = []
unique_frames = set()
detections_per_frame = defaultdict(int)
groups_per_frame = defaultdict(set)
group_entries_per_frame = defaultdict(list)

# Load the JSON data
with open(json_path, 'r') as f:
    data = json.load(f)

# parse valid pedestrian detections and collect all necessary info
for frame_file, objects in data["labels"].items():
    frame_number = int(frame_file.replace(".pcd", ""))
    unique_frames.add(frame_number)

    for obj in objects:
        if obj.get("attributes", {}).get("no_eval", True):
            continue  # Skip invalid detections

        box = obj.get("box", {})
        cx, cy, cz = box.get("cx"), box.get("cy"), box.get("cz")
        length, width, height = box.get("l"), box.get("w"), box.get("h")

        social_group = obj.get("social_group", {})
        group_id = social_group.get("cluster_ID", None)

        # Store parsed info
        gt_entry = {
            "frame": frame_number,
            "label_id": obj.get("label_id"),
            "cx": cx,
            "cy": cy,
            "cz": cz,
            "length": length,
            "width": width,
            "height": height,
            "group_gt": group_id
        }
        ground_truth_detections.append(gt_entry)
        detections_per_frame[frame_number] += 1

        if group_id is not None:
            groups_per_frame[frame_number].add(group_id)
            group_entries_per_frame[frame_number].append((group_id, cx, cy, cz, length, width, height))

# assign local frame-wise group labels and write output
with open(gt_output_path, 'w') as gt_file:
    for frame_number, detections in sorted(group_entries_per_frame.items()):
        # Count how many times each group ID appears in this frame
        group_id_counts = Counter([g[0] for g in detections])

        # Assign new group label
        group_map = {}
        next_group_label = 1
        for gid, count in group_id_counts.items():
            group_map[gid] = next_group_label if count >= 2 else 0
            if count >= 2:
                next_group_label += 1

        # Write out each detection line in new format
        for group_id, cx, cy, cz, length, width, height in detections:
            group_label = group_map[group_id]
            gt_file.write(f"{frame_number},{group_id},{cx},{cy},{cz},{length},{width},{height},{group_label}\n")

# Statistics and sample display
print(f"Total valid ground truth detections: {len(ground_truth_detections)}")
print(f"Total number of unique frames: {len(unique_frames)}")

print("\nDetections and group count per frame (first 10 frames):")
for frame in sorted(detections_per_frame)[:10]:
    num_dets = detections_per_frame[frame]
    num_groups = len(groups_per_frame[frame])
    print(f"Frame {frame}: {num_dets} detections, {num_groups} unique groups")

print("\nSample entries:")
for entry in ground_truth_detections[:5]:
    print(entry)
# Out:
# Total valid ground truth detections: 21437
# Total number of unique frames: 578
#
# Detections and group count per frame (first 10 frames):
# Frame 0: 21 detections, 17 unique groups
# Frame 1: 21 detections, 17 unique groups
# Frame 2: 21 detections, 17 unique groups
# Frame 3: 21 detections, 17 unique groups
# Frame 4: 22 detections, 18 unique groups
# Frame 5: 22 detections, 18 unique groups
# Frame 6: 22 detections, 18 unique groups
# Frame 7: 22 detections, 18 unique groups
# Frame 8: 22 detections, 18 unique groups
# Frame 9: 22 detections, 18 unique groups
#
# Sample entries:
# {'frame': 0, 'label_id': 'pedestrian:96', 'cx': 6.48283, 'cy': -8.3539, 'cz': 0.03798, 'length': 1.06, 'width': 0.52, 'height': 1.93596, 'group_gt': 36}
# {'frame': 0, 'label_id': 'pedestrian:9', 'cx': 4.74, 'cy': -5.97, 'cz': -0.00499, 'length': 0.89, 'width': 0.51, 'height': 1.85003, 'group_gt': 14}
# {'frame': 0, 'label_id': 'pedestrian:63', 'cx': 15.04, 'cy': -7.83, 'cz': 2.79201, 'length': 0.94, 'width': 0.5, 'height': 1.82403, 'group_gt': 19}
# {'frame': 0, 'label_id': 'pedestrian:28', 'cx': 1.18, 'cy': -6.0, 'cz': 0.03997, 'length': 1.02, 'width': 0.5, 'height': 1.93994, 'group_gt': 12}
# {'frame': 0, 'label_id': 'pedestrian:11', 'cx': 0.93, 'cy': -5.28, 'cz': -0.01015, 'length': 0.93, 'width': 0.5, 'height': 1.8397, 'group_gt': 12}

# %%
# Apply Clustering

import os
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from collections import defaultdict

# Load and Parse Ground Truth Data
def load_ground_truth(filename):
    column_names = [
        'frame', 'group_id', 'x', 'y', 'z',
        'length', 'width', 'height', 'group_label'
    ]

    gt_data = pd.read_csv(filename, header=None, names=column_names)
    print(f"Loaded {len(gt_data)} ground truth entries across {gt_data['frame'].nunique()} frames.")

    # Calculate bounding box min/max bounds
    gt_data['x_min'] = gt_data['x'] - gt_data['length'] / 2
    gt_data['x_max'] = gt_data['x'] + gt_data['length'] / 2
    gt_data['y_min'] = gt_data['y'] - gt_data['width'] / 2
    gt_data['y_max'] = gt_data['y'] + gt_data['width'] / 2
    gt_data['z_min'] = gt_data['z'] - gt_data['height'] / 2
    gt_data['z_max'] = gt_data['z'] + gt_data['height'] / 2

    return gt_data


# Compute Distances and Apply Clustering
def detect_groups(gt_data, distance_threshold=2.0):
    result = gt_data.copy()
    result['group'] = 0  # Initialize all as ungrouped (group=0)

    unique_frames = result['frame'].unique()
    print(f"Processing {len(unique_frames)} frames...")

    total_groups = 0

    for frame in unique_frames:
        frame_data = result[result['frame'] == frame]
        frame_indices = frame_data.index

        if len(frame_data) <= 1:
            continue  # Skip frames with only one entry

        # Use box centers for clustering
        coords = frame_data[['x', 'y', 'z']].values

        # Apply DBSCAN clustering
        clustering = DBSCAN(eps=distance_threshold, min_samples=2, metric='euclidean').fit(coords)
        labels = clustering.labels_

        # Convert DBSCAN labels to group IDs (noise = 0)
        group_ids = np.zeros_like(labels)
        label_to_group = {}
        next_group_id = 1

        for i, label in enumerate(labels):
            if label == -1:
                group_ids[i] = 0
            else:
                if label not in label_to_group:
                    label_to_group[label] = next_group_id
                    next_group_id += 1
                group_ids[i] = label_to_group[label]

        result.loc[frame_indices, 'group'] = group_ids

        frame_groups = len(set(group_ids) - {0})
        total_groups += frame_groups

    print(f"Detected {total_groups} groups across all frames.")
    return result


# Save Group Detection Results
def save_group_detections(detections, output_file):
    detections.to_csv(output_file, header=False, index=False)
    print(f"Saved group detection results to {output_file}")


# Main Function
def main():
    input_file = "/content/GT.txt"
    output_file = "/content/gt_group_detections_with_bbox.txt"
    distance_threshold = 2.0  # meters

    print(" Loading and parsing ground truth data...")
    gt_data = load_ground_truth(input_file)

    print("\n Computing distances and clustering into groups...")
    grouped_detections = detect_groups(gt_data, distance_threshold)

    print("\n Saving group detection results...")
    save_group_detections(grouped_detections, output_file)

    # Print Summary
    total_detections = len(grouped_detections)
    grouped = grouped_detections[grouped_detections['group'] > 0]
    ungrouped = grouped_detections[grouped_detections['group'] == 0]

    print("\nResults Summary:")
    print(f"Total entries: {total_detections}")
    print(f"Grouped entries: {len(grouped)} ({len(grouped) / total_detections * 100:.1f}%)")
    print(f"Ungrouped entries: {len(ungrouped)} ({len(ungrouped) / total_detections * 100:.1f}%)")

# Run the script
if __name__ == "__main__":
    main()
# Out:
# Step 1: Loading and parsing ground truth data...
# Loaded 21363 ground truth entries across 578 frames.
#
# Step 2 & 3: Computing distances and clustering into groups...
# Processing 578 frames...
# Detected 4088 groups across all frames.
#
# Step 4: Saving group detection results...
# Saved group detection results to /content/gt_group_detections_with_bbox.txt
#
# Results Summary:
# Total entries: 21363
# Grouped entries: 16982 (79.5%)
# Ungrouped entries: 4381 (20.5%)

# %%
# Clustering performance

import pandas as pd
import numpy as np
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

# Load Grouped Ground Truth with DBSCAN Results
def load_group_detections(file_path):
    col_names = ["frame", "group_id", "x", "y", "z",
                 "length", "width", "height", "group_label",
                 "x_min", "x_max", "y_min", "y_max", "z_min", "z_max", "group"]
    df = pd.read_csv(file_path, header=None, names=col_names)

    # Ensure group label is integer
    df["group"] = df["group"].astype(int)

    print(f"Loaded {len(df)} entries from {file_path}.")
    return df

# Load output file with clustered groups from DBSCAN applied on GT
dbscan_results = load_group_detections("/content/gt_group_detections_with_bbox.txt")


# Compute Clustering Metrics Per Frame
def compute_clustering_metrics(detections):
    silhouette_scores = []
    db_scores = []
    ch_scores = []

    for frame in detections["frame"].unique():
        frame_data = detections[detections["frame"] == frame]
        clustered_data = frame_data[frame_data["group"] != 0]

        if len(set(clustered_data["group"])) > 1:
            # Use the 3D coordinates (bounding box centers)
            X = clustered_data[["x", "y", "z"]].to_numpy()
            labels = clustered_data["group"].to_numpy()

            try:
                sil_score = silhouette_score(X, labels)
                db_index = davies_bouldin_score(X, labels)
                ch_index = calinski_harabasz_score(X, labels)

                silhouette_scores.append(sil_score)
                db_scores.append(db_index)
                ch_scores.append(ch_index)
            except Exception as e:
                print(f"Skipping frame {frame} due to error: {e}")

    return {
        "silhouette_score": np.mean(silhouette_scores) if silhouette_scores else None,
        "davies_bouldin_index": np.mean(db_scores) if db_scores else None,
        "calinski_harabasz_index": np.mean(ch_scores) if ch_scores else None
    }

# Print Evaluation Results
dbscan_metrics = compute_clustering_metrics(dbscan_results)

print("\n===== DBSCAN-Based Clustering Evaluation on GT Bounding Boxes =====")
if dbscan_metrics["silhouette_score"] is not None:
    print(f"Silhouette Score: {dbscan_metrics['silhouette_score']:.3f} (Higher is better)")
else:
    print("Silhouette Score: Not available")

if dbscan_metrics["davies_bouldin_index"] is not None:
    print(f"Davies-Bouldin Index: {dbscan_metrics['davies_bouldin_index']:.3f} (Lower is better)")
else:
    print("Davies-Bouldin Index: Not available")

if dbscan_metrics["calinski_harabasz_index"] is not None:
    print(f"Calinski-Harabasz Index: {dbscan_metrics['calinski_harabasz_index']:.3f} (Higher is better)")
else:
    print("Calinski-Harabasz Index: Not available")
# Out:
# Loaded 21363 entries from /content/gt_group_detections_with_bbox.txt.
#
# ===== DBSCAN-Based Clustering Evaluation on GT Bounding Boxes =====
# Silhouette Score: 0.635 (Higher is better)
# Davies-Bouldin Index: 0.301 (Lower is better)
# Calinski-Harabasz Index: 111.928 (Higher is better)

# %% [markdown]
# **Clustering performance on prediction [(RPEA or DCCLA) + (DBSCAN or KMeans or AHC)]**

# %% [markdown]
# **DBSCAN**

# %%
import os
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN
from collections import defaultdict


# Load and Parse Input Data
def load_detections(filename):

    column_names = [
        'frame', 'id', 'x_center', 'y_center', 'z_center',
        'length', 'width', 'height', 'heading', 'score'
    ]

    # Read the detection file
    detections = pd.read_csv(filename, header=None, names=column_names)
    print(f"Loaded {len(detections)} detections across {detections['frame'].nunique()} frames.")

    return detections


# Compute Distances and Apply Clustering
def detect_groups(detections, distance_threshold=1.0):

    result = detections.copy()
    result['group'] = 0  # Initialize all detections as ungrouped (group=0)

    unique_frames = result['frame'].unique()
    print(f"Processing {len(unique_frames)} frames...")

    total_groups = 0

    for frame in unique_frames:
        frame_detections = result[result['frame'] == frame] # Extract detections for this frame
        frame_indices = result[result['frame'] == frame].index # example output [0, 1, 2, 3, 4, . .]

        if len(frame_detections) <= 1:
            continue  # Skip frames with only one detection

        centers = frame_detections[['x_center', 'y_center', 'z_center']].values

        # Apply DBSCAN clustering
        clustering = DBSCAN(eps=distance_threshold, min_samples=2, metric='euclidean').fit(centers)
        labels = clustering.labels_ # example output [0, 0, 1, 1, -1] Here -1 is noise.

        # Count the number of detections in each group (excluding noise)
        label_counts = defaultdict(int)
        for label in labels:
            if label != -1:
                label_counts[label] += 1

        #If labels =[0, 0, 1, 1, -1, 2, 2, 2, -1], then group_ids =[0, 0, 0, 0, 0, 0, 0, 0, 0]. Default group is 0 (no group)
        group_ids = np.zeros_like(labels)
        label_to_group = {}
        next_group_id = 1

        for i, label in enumerate(labels):
            if label == -1:
                group_ids[i] = 0  # Noise or single detections remain ungrouped
            else:
                if label not in label_to_group:
                    label_to_group[label] = next_group_id
                    next_group_id += 1
                group_ids[i] = label_to_group[label]

        result.loc[frame_indices, 'group'] = group_ids

        frame_groups = len(set(group_ids) - {0})  # Count groups in this frame (excluding 0)
        total_groups += frame_groups

    print(f"Detected {total_groups} groups across all frames.")

    return result


# Save Group Detection Results
def save_group_detections(detections, output_file):
    detections.to_csv(output_file, header=False, index=False)
    print(f"Saved group detection results to {output_file}")


# Main Function
def main():
    input_file = "/content/det.txt"
    output_file = "/content/group_detections.txt"
    distance_threshold = 2.0 # meters

    print("Loading and parsing detection data...")
    detections = load_detections(input_file)

    print("\n Computing distances and clustering into groups...")
    grouped_detections = detect_groups(detections, distance_threshold)

    print("\n Saving group detection results...")
    save_group_detections(grouped_detections, output_file)

    # Print Summary
    total_detections = len(grouped_detections)
    grouped = grouped_detections[grouped_detections['group'] > 0]
    ungrouped = grouped_detections[grouped_detections['group'] == 0]

    print("\nResults Summary:")
    print(f"Total detections: {total_detections}")
    print(f"Detections in groups: {len(grouped)} ({len(grouped) / total_detections * 100:.1f}%)")
    print(f"Ungrouped detections: {len(ungrouped)} ({len(ungrouped) / total_detections * 100:.1f}%)")

# Run the script
if __name__ == "__main__":
    main()
# Out:
# Step 1: Loading and parsing detection data...
# Loaded 14441 detections across 578 frames.
#
# Step 2 & 3: Computing distances and clustering into groups...
# Processing 578 frames...
# Detected 3053 groups across all frames.
#
# Step 4: Saving group detection results...
# Saved group detection results to /content/group_detections.txt
#
# Results Summary:
# Total detections: 14441
# Detections in groups: 7446 (51.6%)
# Ungrouped detections: 6995 (48.4%)

# %% [markdown]
# **KMeans with Elbow method**

# %%
# !pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.5-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: numpy>=1.14.2 in /usr/local/lib/python3.11/dist-packages (from kneed) (2.0.2)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from kneed) (1.15.3)
# Downloading kneed-0.8.5-py3-none-any.whl (10 kB)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.5

# %%
# Elbow Method using KMeans
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from kneed import KneeLocator # Automatically detects the "elbow" point
from collections import defaultdict

# Load and Parse Input Data
def load_detections(filename):
    column_names = [
        'frame', 'id', 'x_center', 'y_center', 'z_center',
        'length', 'width', 'height', 'heading', 'score'
    ]
    detections = pd.read_csv(filename, header=None, names=column_names)
    print(f"Loaded {len(detections)} detections across {detections['frame'].nunique()} frames.")
    return detections

# Clustering Using KMeans + Elbow
def detect_groups_elbow(detections, min_k=2, max_k=6, plot_dir="elbow_plots"):
    os.makedirs(plot_dir, exist_ok=True)

    result = detections.copy()
    result['group'] = 0
    unique_frames = result['frame'].unique()
    print(f"Processing {len(unique_frames)} frames...")

    total_groups = 0

    for frame in unique_frames:
        frame_data = result[result['frame'] == frame]
        frame_indices = frame_data.index

        if len(frame_data) < min_k:
            print(f"Frame {frame}: Not enough detections to cluster.")
            continue

        coords = frame_data[['x_center', 'y_center', 'z_center']].to_numpy()
        inertias = [] # Inertia = Within-Cluster Sum of Squares (WCSS)
        k_values = list(range(min_k, min(max_k + 1, len(coords) + 1)))

        for k in k_values:
            kmeans = KMeans(n_clusters=k, n_init='auto', random_state=0)
            kmeans.fit(coords)
            inertias.append(kmeans.inertia_)

        best_k = None
        if len(inertias) >= 2:
            try:
                kl = KneeLocator(k_values, inertias, curve='convex', direction='decreasing')
                best_k = kl.elbow
            except:
                best_k = None

        # Plot elbow
        plt.figure()
        plt.plot(k_values, inertias, 'bo-')
        plt.xlabel("Number of Clusters (k)")
        plt.ylabel("Inertia")
        plt.title(f"Elbow Plot - Frame {frame}")
        plt.grid(True)
        plt.savefig(os.path.join(plot_dir, f"frame_{frame:04d}.png"))
        plt.close()

        if best_k is None:
            print(f"Frame {frame}: Elbow point not found. Marking all as ungrouped.")
            result.loc[frame_indices, 'group'] = 0
        else:
            kmeans = KMeans(n_clusters=best_k, n_init='auto', random_state=0)
            labels = kmeans.fit_predict(coords)
            result.loc[frame_indices, 'group'] = labels + 1  # groups start from 1
            print(f"Frame {frame}: Optimal k = {best_k}, Inertia = {kmeans.inertia_:.2f}")
            total_groups += len(set(labels))

    print(f"Detected {total_groups} groups across all frames.")
    return result

# Save Results
def save_group_detections(detections, output_file):
    detections.to_csv(output_file, header=False, index=False)
    print(f"Saved group detection results to {output_file}")

# MAIN Function
def main():
    input_file = "/content/det.txt"
    output_file = "/content/group_detections_elbow.txt"
    plot_dir = "/content/elbow_plots"

    print(" Loading and parsing detection data...")
    detections = load_detections(input_file)

    print("\n Clustering into groups using Elbow Method...")
    grouped_detections = detect_groups_elbow(detections, plot_dir=plot_dir)

    print("\n Saving group detection results...")
    save_group_detections(grouped_detections, output_file)

    total_detections = len(grouped_detections)
    grouped = grouped_detections[grouped_detections['group'] > 0]
    ungrouped = grouped_detections[grouped_detections['group'] == 0]
    print("\nResults Summary:")
    print(f"Total detections: {total_detections}")
    print(f"Detections in groups: {len(grouped)} ({len(grouped) / total_detections * 100:.1f}%)")
    print(f"Ungrouped detections: {len(ungrouped)} ({len(ungrouped) / total_detections * 100:.1f}%)")

# Run the script
if __name__ == "__main__":
    main()
# Out:
# Step 1: Loading and parsing detection data...
# Loaded 14441 detections across 578 frames.
#
# Step 2 & 3: Clustering into groups using Elbow Method...
# Processing 578 frames...
# Frame 0: Optimal k = 4, Inertia = 898.31
# Frame 1: Elbow point not found. Marking all as ungrouped.
# Frame 2: Optimal k = 3, Inertia = 887.52
# Frame 3: Optimal k = 4, Inertia = 650.93
# Frame 4: Elbow point not found. Marking all as ungrouped.
# Frame 5: Optimal k = 3, Inertia = 1219.43
# Frame 6: Optimal k = 3, Inertia = 1564.84
# Frame 7: Elbow point not found. Marking all as ungrouped.
# Frame 8: Elbow point not found. Marking all as ungrouped.
# Frame 9: Elbow point not found. Marking all as ungrouped.
# Frame 10: Elbow point not found. Marking all as ungrouped.
# Frame 11: Optimal k = 4, Inertia = 667.76
# Frame 12: Elbow point not found. Marking all as ungrouped.
# Frame 13: Elbow point not found. Marking all as ungrouped.
# Frame 14: Elbow point not found. Marking all as ungrouped.
# Frame 15: Optimal k = 3, Inertia = 906.64
# Frame 16: Optimal k = 4, Inertia = 1657.40
# Frame 17: Elbow point not found. Marking all as ungrouped.
# Frame 18: Elbow point not found. Marking all as ungrouped.
# Frame 19: Optimal k = 4, Inertia = 588.16
# Frame 20: Optimal k = 3, Inertia = 641.71
# Frame 21: Optimal k = 3, Inertia = 1038.32
# Frame 22: Optimal k = 4, Inertia = 340.27
# Frame 23: Optimal k = 3, Inertia = 1493.89
# Frame 24: Optimal k = 4, Inertia = 488.49
# Frame 25: Elbow point not found. Marking all as ungrouped.
# Frame 26: Optimal k = 3, Inertia = 1950.80
# Frame 27: Elbow point not found. Marking all as ungrouped.
# Frame 28: Optimal k = 3, Inertia = 1443.88
# Frame 29: Elbow point not found. Marking all as ungrouped.
# Frame 30: Optimal k = 4, Inertia = 901.98
# Frame 31: Optimal k = 4, Inertia = 660.44
# Frame 32: Elbow point not found. Marking all as ungrouped.
# Frame 33: Optimal k = 3, Inertia = 2526.23
# Frame 34: Optimal k = 4, Inertia = 710.24
# Frame 35: Elbow point not found. Marking all as ungrouped.
# Frame 36: Optimal k = 4, Inertia = 772.70
# Frame 37: Optimal k = 4, Inertia = 892.73
# Frame 38: Optimal k = 3, Inertia = 1611.09
# Frame 39: Optimal k = 3, Inertia = 1332.69
# Frame 40: Optimal k = 4, Inertia = 780.52
# Frame 41: Optimal k = 3, Inertia = 1150.15
# Frame 42: Optimal k = 4, Inertia = 647.14
# Frame 43: Elbow point not found. Marking all as ungrouped.
# Frame 44: Optimal k = 3, Inertia = 715.65
# Frame 45: Optimal k = 3, Inertia = 1214.99
# Frame 46: Optimal k = 4, Inertia = 594.08
# Frame 47: Elbow point not found. Marking all as ungrouped.
# Frame 48: Elbow point not found. Marking all as ungrouped.
# Frame 49: Optimal k = 4, Inertia = 405.84
# Frame 50: Optimal k = 4, Inertia = 931.59
# Frame 51: Optimal k = 4, Inertia = 358.03
# Frame 52: Elbow point not found. Marking all as ungrouped.
# Frame 53: Optimal k = 4, Inertia = 695.11
# Frame 54: Elbow point not found. Marking all as ungrouped.
# Frame 55: Optimal k = 3, Inertia = 1076.77
# Frame 56: Elbow point not found. Marking all as ungrouped.
# Frame 57: Optimal k = 3, Inertia = 1162.44
# Frame 58: Elbow point not found. Marking all as ungrouped.
# Frame 59: Elbow point not found. Marking all as ungrouped.
# Frame 60: Elbow point not found. Marking all as ungrouped.
# Frame 61: Elbow point not found. Marking all as ungrouped.
# Frame 62: Elbow point not found. Marking all as ungrouped.
# Frame 63: Optimal k = 3, Inertia = 1118.77
# Frame 64: Optimal k = 3, Inertia = 2106.29
# Frame 65: Optimal k = 4, Inertia = 1058.81
# Frame 66: Elbow point not found. Marking all as ungrouped.
# Frame 67: Elbow point not found. Marking all as ungrouped.
# Frame 68: Elbow point not found. Marking all as ungrouped.
# Frame 69: Optimal k = 4, Inertia = 636.44
# Frame 70: Optimal k = 4, Inertia = 1028.57
# Frame 71: Optimal k = 4, Inertia = 874.08
# Frame 72: Optimal k = 4, Inertia = 385.06
# Frame 73: Elbow point not found. Marking all as ungrouped.
# Frame 74: Elbow point not found. Marking all as ungrouped.
# Frame 75: Elbow point not found. Marking all as ungrouped.
# Frame 76: Optimal k = 4, Inertia = 833.43
# Frame 77: Optimal k = 3, Inertia = 2032.09
# Frame 78: Elbow point not found. Marking all as ungrouped.
# Frame 79: Optimal k = 3, Inertia = 2076.26
# Frame 80: Elbow point not found. Marking all as ungrouped.
# Frame 81: Elbow point not found. Marking all as ungrouped.
# Frame 82: Elbow point not found. Marking all as ungrouped.
# Frame 83: Optimal k = 4, Inertia = 1619.58
# Frame 84: Optimal k = 4, Inertia = 791.85
# Frame 85: Optimal k = 4, Inertia = 783.66
# Frame 86: Optimal k = 3, Inertia = 2392.08
# Frame 87: Elbow point not found. Marking all as ungrouped.
# Frame 88: Elbow point not found. Marking all as ungrouped.
# Frame 89: Optimal k = 4, Inertia = 500.12
# Frame 90: Optimal k = 4, Inertia = 784.74
# Frame 91: Optimal k = 4, Inertia = 1100.75
# Frame 92: Optimal k = 3, Inertia = 889.42
# Frame 93: Optimal k = 4, Inertia = 897.34
# Frame 94: Optimal k = 4, Inertia = 824.92
# Frame 95: Optimal k = 3, Inertia = 717.85
# Frame 96: Optimal k = 3, Inertia = 1212.96
# Frame 97: Optimal k = 4, Inertia = 237.00
# Frame 98: Optimal k = 3, Inertia = 471.53
# Frame 99: Elbow point not found. Marking all as ungrouped.
# Frame 100: Elbow point not found. Marking all as ungrouped.
# Frame 101: Optimal k = 4, Inertia = 1080.61
# Frame 102: Elbow point not found. Marking all as ungrouped.
# Frame 103: Optimal k = 4, Inertia = 763.67
# Frame 104: Elbow point not found. Marking all as ungrouped.
# Frame 105: Optimal k = 3, Inertia = 668.57
# Frame 106: Optimal k = 3, Inertia = 1146.20
# Frame 107: Elbow point not found. Marking all as ungrouped.
# Frame 108: Optimal k = 3, Inertia = 1048.92
# Frame 109: Optimal k = 3, Inertia = 817.29
# Frame 110: Optimal k = 3, Inertia = 709.53
# Frame 111: Optimal k = 3, Inertia = 989.55
# Frame 112: Elbow point not found. Marking all as ungrouped.
# Frame 113: Optimal k = 4, Inertia = 512.61
# Frame 114: Optimal k = 4, Inertia = 623.86
# Frame 115: Optimal k = 3, Inertia = 761.19
# Frame 116: Elbow point not found. Marking all as ungrouped.
# Frame 117: Optimal k = 3, Inertia = 860.55
# Frame 118: Optimal k = 4, Inertia = 750.40
# Frame 119: Optimal k = 3, Inertia = 386.74
# Frame 120: Optimal k = 3, Inertia = 844.50
# Frame 121: Optimal k = 4, Inertia = 561.57
# Frame 122: Optimal k = 3, Inertia = 1146.09
# Frame 123: Elbow point not found. Marking all as ungrouped.
# Frame 124: Optimal k = 3, Inertia = 1206.73
# Frame 125: Optimal k = 3, Inertia = 1744.99
# Frame 126: Elbow point not found. Marking all as ungrouped.
# Frame 127: Elbow point not found. Marking all as ungrouped.
# Frame 128: Optimal k = 4, Inertia = 1471.86
# Frame 129: Optimal k = 4, Inertia = 951.65
# Frame 130: Optimal k = 4, Inertia = 814.87
# Frame 131: Optimal k = 3, Inertia = 647.00
# Frame 132: Optimal k = 3, Inertia = 921.42
# Frame 133: Elbow point not found. Marking all as ungrouped.
# Frame 134: Optimal k = 3, Inertia = 673.50
# Frame 135: Elbow point not found. Marking all as ungrouped.
# Frame 136: Optimal k = 4, Inertia = 773.29
# Frame 137: Elbow point not found. Marking all as ungrouped.
# Frame 138: Elbow point not found. Marking all as ungrouped.
# Frame 139: Optimal k = 3, Inertia = 858.70
# Frame 140: Elbow point not found. Marking all as ungrouped.
# Frame 141: Elbow point not found. Marking all as ungrouped.
# Frame 142: Elbow point not found. Marking all as ungrouped.
# Frame 143: Optimal k = 3, Inertia = 1456.33
# Frame 144: Optimal k = 3, Inertia = 1354.56
# Frame 145: Elbow point not found. Marking all as ungrouped.
# Frame 146: Elbow point not found. Marking all as ungrouped.
# Frame 147: Optimal k = 3, Inertia = 1304.93
# Frame 148: Optimal k = 3, Inertia = 957.12
# Frame 149: Optimal k = 3, Inertia = 747.89
# Frame 150: Optimal k = 3, Inertia = 1934.71
# Frame 151: Optimal k = 4, Inertia = 808.47
# Frame 152: Optimal k = 4, Inertia = 953.03
# Frame 153: Optimal k = 3, Inertia = 1217.65
# Frame 154: Elbow point not found. Marking all as ungrouped.
# Frame 155: Optimal k = 4, Inertia = 533.65
# Frame 156: Optimal k = 3, Inertia = 1465.16
# Frame 157: Elbow point not found. Marking all as ungrouped.
# Frame 158: Optimal k = 4, Inertia = 629.01
# Frame 159: Elbow point not found. Marking all as ungrouped.
# Frame 160: Elbow point not found. Marking all as ungrouped.
# Frame 161: Optimal k = 4, Inertia = 1170.69
# Frame 162: Optimal k = 4, Inertia = 1076.99
# Frame 163: Elbow point not found. Marking all as ungrouped.
# Frame 164: Optimal k = 4, Inertia = 1422.69
# Frame 165: Elbow point not found. Marking all as ungrouped.
# Frame 166: Elbow point not found. Marking all as ungrouped.
# Frame 167: Elbow point not found. Marking all as ungrouped.
# Frame 168: Elbow point not found. Marking all as ungrouped.
# Frame 169: Elbow point not found. Marking all as ungrouped.
# Frame 170: Optimal k = 3, Inertia = 633.65
# Frame 171: Optimal k = 3, Inertia = 808.60
# Frame 172: Elbow point not found. Marking all as ungrouped.
# Frame 173: Elbow point not found. Marking all as ungrouped.
# Frame 174: Optimal k = 4, Inertia = 786.47
# Frame 175: Optimal k = 4, Inertia = 936.44
# Frame 176: Optimal k = 3, Inertia = 677.78
# Frame 177: Optimal k = 3, Inertia = 1436.36
# Frame 178: Optimal k = 4, Inertia = 987.05
# Frame 179: Elbow point not found. Marking all as ungrouped.
# Frame 180: Optimal k = 4, Inertia = 1285.96
# Frame 181: Elbow point not found. Marking all as ungrouped.
# Frame 182: Optimal k = 4, Inertia = 339.55
# Frame 183: Elbow point not found. Marking all as ungrouped.
# Frame 184: Optimal k = 3, Inertia = 1842.93
# Frame 185: Optimal k = 3, Inertia = 1734.21
# Frame 186: Optimal k = 3, Inertia = 895.15
# Frame 187: Optimal k = 4, Inertia = 646.31
# Frame 188: Elbow point not found. Marking all as ungrouped.
# Frame 189: Elbow point not found. Marking all as ungrouped.
# Frame 190: Optimal k = 4, Inertia = 696.38
# Frame 191: Optimal k = 4, Inertia = 1019.16
# Frame 192: Elbow point not found. Marking all as ungrouped.
# Frame 193: Optimal k = 4, Inertia = 965.68
# Frame 194: Optimal k = 4, Inertia = 777.91
# Frame 195: Elbow point not found. Marking all as ungrouped.
# Frame 196: Optimal k = 3, Inertia = 1076.90
# Frame 197: Elbow point not found. Marking all as ungrouped.
# Frame 198: Optimal k = 3, Inertia = 1964.54
# Frame 199: Optimal k = 4, Inertia = 300.51
# Frame 200: Optimal k = 4, Inertia = 462.86
# Frame 201: Optimal k = 3, Inertia = 1674.42
# Frame 489: Optimal k = 3, Inertia = 655.21
# Frame 490: Optimal k = 4, Inertia = 1641.57
# Frame 491: Elbow point not found. Marking all as ungrouped.
# Frame 492: Optimal k = 4, Inertia = 1299.01
# Frame 493: Optimal k = 3, Inertia = 1966.06
# Frame 494: Elbow point not found. Marking all as ungrouped.
# Frame 495: Elbow point not found. Marking all as ungrouped.
# Frame 496: Elbow point not found. Marking all as ungrouped.
# Frame 497: Optimal k = 4, Inertia = 1482.12
# Frame 498: Optimal k = 3, Inertia = 2323.35
# Frame 499: Elbow point not found. Marking all as ungrouped.
# Frame 500: Elbow point not found. Marking all as ungrouped.
# Frame 501: Optimal k = 3, Inertia = 2154.01
# Frame 502: Optimal k = 3, Inertia = 2084.63
# Frame 503: Elbow point not found. Marking all as ungrouped.
# Frame 504: Optimal k = 3, Inertia = 2157.38
# Frame 505: Optimal k = 3, Inertia = 1885.13
# Frame 506: Optimal k = 3, Inertia = 1403.37
# Frame 507: Optimal k = 4, Inertia = 1024.11
# Frame 508: Optimal k = 3, Inertia = 1199.14
# Frame 509: Optimal k = 4, Inertia = 1294.83
# Frame 510: Optimal k = 3, Inertia = 1289.46
# Frame 511: Optimal k = 3, Inertia = 1250.67
# Frame 512: Optimal k = 3, Inertia = 1161.63
# Frame 513: Optimal k = 3, Inertia = 1081.33
# Frame 514: Elbow point not found. Marking all as ungrouped.
# Frame 515: Optimal k = 4, Inertia = 950.18
# Frame 516: Elbow point not found. Marking all as ungrouped.
# Frame 517: Elbow point not found. Marking all as ungrouped.
# Frame 518: Elbow point not found. Marking all as ungrouped.
# Frame 519: Elbow point not found. Marking all as ungrouped.
# Frame 520: Elbow point not found. Marking all as ungrouped.
# Frame 521: Optimal k = 4, Inertia = 427.08
# Frame 522: Optimal k = 4, Inertia = 1100.17
# Frame 523: Optimal k = 4, Inertia = 1411.13
# Frame 524: Optimal k = 4, Inertia = 1331.98
# Frame 525: Optimal k = 3, Inertia = 2136.21
# Frame 526: Elbow point not found. Marking all as ungrouped.
# Frame 527: Optimal k = 2, Inertia = 2911.29
# Frame 528: Optimal k = 4, Inertia = 1515.04
# Frame 529: Elbow point not found. Marking all as ungrouped.
# Frame 530: Optimal k = 3, Inertia = 1697.22
# Frame 531: Elbow point not found. Marking all as ungrouped.
# Frame 532: Optimal k = 3, Inertia = 1160.93
# Frame 533: Optimal k = 4, Inertia = 837.69
# Frame 534: Elbow point not found. Marking all as ungrouped.
# Frame 535: Elbow point not found. Marking all as ungrouped.
# Frame 536: Elbow point not found. Marking all as ungrouped.
# Frame 537: Elbow point not found. Marking all as ungrouped.
# Frame 538: Elbow point not found. Marking all as ungrouped.
# Frame 539: Optimal k = 3, Inertia = 1484.60
# Frame 540: Elbow point not found. Marking all as ungrouped.
# Frame 541: Optimal k = 4, Inertia = 773.15
# Frame 542: Optimal k = 3, Inertia = 1633.28
# Frame 543: Optimal k = 4, Inertia = 911.53
# Frame 544: Optimal k = 4, Inertia = 993.75
# Frame 545: Optimal k = 3, Inertia = 1881.60
# Frame 546: Optimal k = 3, Inertia = 1183.09
# Frame 547: Elbow point not found. Marking all as ungrouped.
# Frame 548: Optimal k = 4, Inertia = 1639.39
# Frame 549: Optimal k = 4, Inertia = 1267.33
# Frame 550: Optimal k = 4, Inertia = 588.46
# Frame 551: Optimal k = 4, Inertia = 1011.23
# Frame 552: Optimal k = 3, Inertia = 1135.36
# Frame 553: Optimal k = 4, Inertia = 1289.92
# Frame 554: Elbow point not found. Marking all as ungrouped.
# Frame 555: Optimal k = 3, Inertia = 1878.67
# Frame 556: Elbow point not found. Marking all as ungrouped.
# Frame 557: Optimal k = 3, Inertia = 1305.39
# Frame 558: Optimal k = 4, Inertia = 1410.63
# Frame 559: Optimal k = 4, Inertia = 1068.58
# Frame 560: Optimal k = 4, Inertia = 866.11
# Frame 561: Elbow point not found. Marking all as ungrouped.
# Frame 562: Elbow point not found. Marking all as ungrouped.
# Frame 563: Optimal k = 4, Inertia = 1078.95
# Frame 564: Optimal k = 4, Inertia = 1301.58
# Frame 565: Optimal k = 3, Inertia = 2009.97
# Frame 566: Optimal k = 3, Inertia = 1437.74
# Frame 567: Optimal k = 4, Inertia = 1118.90
# Frame 568: Optimal k = 3, Inertia = 1306.33
# Frame 569: Optimal k = 4, Inertia = 914.79
# Frame 570: Optimal k = 4, Inertia = 847.04
# Frame 571: Optimal k = 3, Inertia = 1407.52
# Frame 572: Elbow point not found. Marking all as ungrouped.
# Frame 573: Optimal k = 4, Inertia = 665.48
# Frame 574: Optimal k = 4, Inertia = 774.33
# Frame 575: Optimal k = 4, Inertia = 715.08
# Frame 576: Optimal k = 4, Inertia = 436.00
# Frame 577: Optimal k = 4, Inertia = 756.27
# Detected 1362 groups across all frames.
#
# Step 4: Saving group detection results...
# Saved group detection results to /content/group_detections_elbow.txt
#
# Results Summary:
# Total detections: 14441
# Detections in groups: 9503 (65.8%)
# Ungrouped detections: 4938 (34.2%)

# %% [markdown]
# **Hierarchical Agglomerative Clustering (AHC) with k via Elbow**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import pairwise_distances
from scipy.cluster.hierarchy import linkage
from kneed import KneeLocator


# Load and Parse Input Data
def load_detections(filename):
    column_names = [
        'frame', 'id', 'x_center', 'y_center', 'z_center',
        'length', 'width', 'height', 'heading', 'score'
    ]
    detections = pd.read_csv(filename, header=None, names=column_names)
    print(f"Loaded {len(detections)} detections across {detections['frame'].nunique()} frames.")
    return detections


# Clustering Using Agglomerative + Elbow
def detect_groups_hierarchical_elbow(detections, min_k=2, max_k=6, plot_dir="hierarchical_elbow_plots"):
    os.makedirs(plot_dir, exist_ok=True)

    result = detections.copy()
    result['group'] = 0
    unique_frames = result['frame'].unique()
    print(f"Processing {len(unique_frames)} frames...")

    total_groups = 0

    for frame in unique_frames:
        frame_data = result[result['frame'] == frame]
        frame_indices = frame_data.index

        if len(frame_data) < min_k:
            print(f"Frame {frame}: Not enough detections to cluster.")
            continue

        coords = frame_data[['x_center', 'y_center', 'z_center']].to_numpy()
        k_values = list(range(min_k, min(max_k + 1, len(coords) + 1)))

        inertias = []
        Z = linkage(coords, method='ward')  # hierarchical linkage

        for k in k_values:
            clustering = AgglomerativeClustering(n_clusters=k)
            labels = clustering.fit_predict(coords)
            centers = np.array([coords[labels == i].mean(axis=0) for i in range(k)])
            inertia = np.sum([
                np.sum(np.linalg.norm(coords[labels == i] - centers[i], axis=1) ** 2)
                for i in range(k)
            ])
            inertias.append(inertia)

        best_k = None
        if len(inertias) >= 2:
            try:
                kl = KneeLocator(k_values, inertias, curve='convex', direction='decreasing')
                best_k = kl.elbow
            except:
                best_k = None

        # Plot Elbow
        plt.figure()
        plt.plot(k_values, inertias, 'ro-')
        plt.xlabel("Number of Clusters (k)")
        plt.ylabel("Inertia (Within-cluster sum of squares)")
        plt.title(f"Hierarchical Elbow - Frame {frame}")
        plt.grid(True)
        plt.savefig(os.path.join(plot_dir, f"frame_{frame:04d}.png"))
        plt.close()

        if best_k is None:
            print(f"Frame {frame}: Elbow point not found. Marking all as ungrouped.")
            result.loc[frame_indices, 'group'] = 0
        else:
            clustering = AgglomerativeClustering(n_clusters=best_k)
            labels = clustering.fit_predict(coords)
            result.loc[frame_indices, 'group'] = labels + 1
            print(f"Frame {frame}: Optimal k = {best_k}, Inertia = {inertias[best_k - min_k]:.2f}")
            total_groups += len(set(labels))

    print(f"Detected {total_groups} groups across all frames.")
    return result


# Save Results
def save_group_detections(detections, output_file):
    detections.to_csv(output_file, header=False, index=False)
    print(f"Saved group detection results to {output_file}")


# MAIN Function
def main():
    input_file = "/content/det.txt"
    output_file = "/content/group_detections_hierarchical.txt"
    plot_dir = "/content/hierarchical_elbow_plots"

    print("Loading and parsing detection data...")
    detections = load_detections(input_file)

    print("\n Clustering into groups using Hierarchical Clustering + Elbow Method...")
    grouped_detections = detect_groups_hierarchical_elbow(detections, plot_dir=plot_dir)

    print("\n Saving group detection results...")
    save_group_detections(grouped_detections, output_file)

    total_detections = len(grouped_detections)
    grouped = grouped_detections[grouped_detections['group'] > 0]
    ungrouped = grouped_detections[grouped_detections['group'] == 0]
    print("\nResults Summary:")
    print(f"Total detections: {total_detections}")
    print(f"Detections in groups: {len(grouped)} ({len(grouped) / total_detections * 100:.1f}%)")
    print(f"Ungrouped detections: {len(ungrouped)} ({len(ungrouped) / total_detections * 100:.1f}%)")


# Run the script
if __name__ == "__main__":
    main()
# Out:
# Step 1: Loading and parsing detection data...
# Loaded 14441 detections across 578 frames.
#
# Step 2 & 3: Clustering into groups using Hierarchical Clustering + Elbow Method...
# Processing 578 frames...
# Frame 0: Optimal k = 4, Inertia = 898.31
# Frame 1: Elbow point not found. Marking all as ungrouped.
# Frame 2: Optimal k = 4, Inertia = 560.35
# Frame 3: Optimal k = 3, Inertia = 1069.99
# Frame 4: Elbow point not found. Marking all as ungrouped.
# Frame 5: Elbow point not found. Marking all as ungrouped.
# Frame 6: Optimal k = 3, Inertia = 1505.12
# Frame 7: Optimal k = 4, Inertia = 1035.08
# Frame 8: Optimal k = 4, Inertia = 829.55
# Frame 9: Optimal k = 4, Inertia = 704.20
# Frame 10: Elbow point not found. Marking all as ungrouped.
# Frame 11: Optimal k = 4, Inertia = 667.76
# Frame 12: Elbow point not found. Marking all as ungrouped.
# Frame 13: Optimal k = 3, Inertia = 833.67
# Frame 14: Elbow point not found. Marking all as ungrouped.
# Frame 15: Optimal k = 4, Inertia = 530.75
# Frame 16: Elbow point not found. Marking all as ungrouped.
# Frame 17: Elbow point not found. Marking all as ungrouped.
# Frame 18: Optimal k = 3, Inertia = 1185.42
# Frame 19: Optimal k = 4, Inertia = 632.95
# Frame 20: Optimal k = 4, Inertia = 400.33
# Frame 21: Elbow point not found. Marking all as ungrouped.
# Frame 22: Optimal k = 3, Inertia = 707.69
# Frame 23: Optimal k = 4, Inertia = 883.76
# Frame 24: Optimal k = 4, Inertia = 488.49
# Frame 25: Elbow point not found. Marking all as ungrouped.
# Frame 26: Optimal k = 4, Inertia = 932.34
# Frame 27: Optimal k = 4, Inertia = 1052.43
# Frame 28: Optimal k = 4, Inertia = 840.02
# Frame 29: Optimal k = 3, Inertia = 1810.83
# Frame 30: Optimal k = 4, Inertia = 901.98
# Frame 31: Elbow point not found. Marking all as ungrouped.
# Frame 32: Elbow point not found. Marking all as ungrouped.
# Frame 33: Elbow point not found. Marking all as ungrouped.
# Frame 34: Optimal k = 3, Inertia = 1271.03
# Frame 35: Elbow point not found. Marking all as ungrouped.
# Frame 36: Optimal k = 3, Inertia = 1408.23
# Frame 37: Optimal k = 4, Inertia = 927.79
# Frame 38: Optimal k = 3, Inertia = 1611.09
# Frame 39: Optimal k = 4, Inertia = 843.68
# Frame 40: Optimal k = 4, Inertia = 726.66
# Frame 41: Optimal k = 4, Inertia = 638.61
# Frame 42: Optimal k = 4, Inertia = 692.42
# Frame 43: Elbow point not found. Marking all as ungrouped.
# Frame 44: Optimal k = 3, Inertia = 677.39
# Frame 45: Optimal k = 3, Inertia = 944.92
# Frame 46: Optimal k = 4, Inertia = 594.08
# Frame 47: Elbow point not found. Marking all as ungrouped.
# Frame 48: Elbow point not found. Marking all as ungrouped.
# Frame 49: Optimal k = 4, Inertia = 419.62
# Frame 50: Optimal k = 4, Inertia = 880.44
# Frame 51: Optimal k = 3, Inertia = 629.69
# Frame 52: Elbow point not found. Marking all as ungrouped.
# Frame 53: Optimal k = 3, Inertia = 1016.98
# Frame 54: Elbow point not found. Marking all as ungrouped.
# Frame 55: Optimal k = 4, Inertia = 667.32
# Frame 56: Elbow point not found. Marking all as ungrouped.
# Frame 57: Optimal k = 3, Inertia = 1294.34
# Frame 58: Elbow point not found. Marking all as ungrouped.
# Frame 59: Elbow point not found. Marking all as ungrouped.
# Frame 60: Optimal k = 4, Inertia = 679.75
# Frame 61: Elbow point not found. Marking all as ungrouped.
# Frame 62: Optimal k = 4, Inertia = 803.35
# Frame 63: Optimal k = 4, Inertia = 772.13
# Frame 64: Optimal k = 4, Inertia = 1382.36
# Frame 65: Optimal k = 4, Inertia = 1059.54
# Frame 66: Elbow point not found. Marking all as ungrouped.
# Frame 67: Elbow point not found. Marking all as ungrouped.
# Frame 68: Optimal k = 4, Inertia = 831.20
# Frame 69: Optimal k = 3, Inertia = 986.18
# Frame 70: Optimal k = 4, Inertia = 1039.99
# Frame 71: Optimal k = 4, Inertia = 923.06
# Frame 72: Optimal k = 3, Inertia = 730.22
# Frame 73: Optimal k = 3, Inertia = 2168.20
# Frame 74: Elbow point not found. Marking all as ungrouped.
# Frame 75: Elbow point not found. Marking all as ungrouped.
# Frame 76: Optimal k = 4, Inertia = 833.43
# Frame 77: Optimal k = 4, Inertia = 1253.12
# Frame 78: Elbow point not found. Marking all as ungrouped.
# Frame 79: Optimal k = 3, Inertia = 2084.57
# Frame 80: Elbow point not found. Marking all as ungrouped.
# Frame 81: Elbow point not found. Marking all as ungrouped.
# Frame 82: Elbow point not found. Marking all as ungrouped.
# Frame 83: Elbow point not found. Marking all as ungrouped.
# Frame 84: Optimal k = 4, Inertia = 795.34
# Frame 85: Elbow point not found. Marking all as ungrouped.
# Frame 86: Optimal k = 3, Inertia = 2342.13
# Frame 87: Elbow point not found. Marking all as ungrouped.
# Frame 88: Elbow point not found. Marking all as ungrouped.
# Frame 89: Optimal k = 4, Inertia = 500.12
# Frame 90: Optimal k = 4, Inertia = 784.74
# Frame 91: Optimal k = 4, Inertia = 1277.64
# Frame 92: Optimal k = 3, Inertia = 889.42
# Frame 93: Optimal k = 4, Inertia = 932.75
# Frame 94: Optimal k = 3, Inertia = 1351.04
# Frame 95: Optimal k = 3, Inertia = 717.85
# Frame 96: Optimal k = 3, Inertia = 1212.96
# Frame 97: Optimal k = 3, Inertia = 529.49
# Frame 98: Optimal k = 3, Inertia = 471.53
# Frame 99: Elbow point not found. Marking all as ungrouped.
# Frame 100: Elbow point not found. Marking all as ungrouped.
# Frame 101: Elbow point not found. Marking all as ungrouped.
# Frame 102: Elbow point not found. Marking all as ungrouped.
# Frame 103: Optimal k = 3, Inertia = 1304.80
# Frame 104: Optimal k = 3, Inertia = 1117.31
# Frame 105: Optimal k = 3, Inertia = 723.92
# Frame 106: Optimal k = 3, Inertia = 1188.62
# Frame 107: Elbow point not found. Marking all as ungrouped.
# Frame 108: Optimal k = 3, Inertia = 1132.59
# Frame 109: Optimal k = 3, Inertia = 869.35
# Frame 110: Optimal k = 3, Inertia = 736.98
# Frame 111: Optimal k = 3, Inertia = 986.88
# Frame 112: Elbow point not found. Marking all as ungrouped.
# Frame 113: Elbow point not found. Marking all as ungrouped.
# Frame 114: Elbow point not found. Marking all as ungrouped.
# Frame 115: Elbow point not found. Marking all as ungrouped.
# Frame 116: Optimal k = 4, Inertia = 953.71
# Frame 117: Optimal k = 3, Inertia = 860.55
# Frame 118: Optimal k = 3, Inertia = 1099.78
# Frame 119: Optimal k = 3, Inertia = 412.92
# Frame 120: Optimal k = 3, Inertia = 844.50
# Frame 121: Optimal k = 3, Inertia = 845.44
# Frame 122: Optimal k = 4, Inertia = 610.34
# Frame 123: Elbow point not found. Marking all as ungrouped.
# Frame 124: Optimal k = 3, Inertia = 1241.74
# Frame 125: Elbow point not found. Marking all as ungrouped.
# Frame 126: Elbow point not found. Marking all as ungrouped.
# Frame 127: Elbow point not found. Marking all as ungrouped.
# Frame 128: Elbow point not found. Marking all as ungrouped.
# Frame 129: Elbow point not found. Marking all as ungrouped.
# Frame 130: Optimal k = 4, Inertia = 824.54
# Frame 131: Elbow point not found. Marking all as ungrouped.
# Frame 132: Optimal k = 3, Inertia = 949.50
# Frame 133: Elbow point not found. Marking all as ungrouped.
# Frame 134: Elbow point not found. Marking all as ungrouped.
# Frame 135: Optimal k = 3, Inertia = 833.52
# Frame 136: Optimal k = 4, Inertia = 773.29
# Frame 137: Elbow point not found. Marking all as ungrouped.
# Frame 138: Elbow point not found. Marking all as ungrouped.
# Frame 139: Elbow point not found. Marking all as ungrouped.
# Frame 140: Elbow point not found. Marking all as ungrouped.
# Frame 141: Optimal k = 4, Inertia = 1030.77
# Frame 142: Elbow point not found. Marking all as ungrouped.
# Frame 143: Optimal k = 3, Inertia = 1456.33
# Frame 144: Optimal k = 3, Inertia = 1354.56
# Frame 145: Elbow point not found. Marking all as ungrouped.
# Frame 146: Elbow point not found. Marking all as ungrouped.
# Frame 147: Optimal k = 3, Inertia = 1304.93
# Frame 148: Optimal k = 3, Inertia = 957.12
# Frame 149: Optimal k = 3, Inertia = 747.89
# Frame 150: Optimal k = 3, Inertia = 1934.71
# Frame 151: Optimal k = 3, Inertia = 1267.17
# Frame 152: Optimal k = 4, Inertia = 1039.19
# Frame 153: Elbow point not found. Marking all as ungrouped.
# Frame 154: Elbow point not found. Marking all as ungrouped.
# Frame 155: Elbow point not found. Marking all as ungrouped.
# Frame 156: Optimal k = 3, Inertia = 1465.16
# Frame 157: Elbow point not found. Marking all as ungrouped.
# Frame 158: Optimal k = 3, Inertia = 1051.80
# Frame 159: Elbow point not found. Marking all as ungrouped.
# Frame 160: Elbow point not found. Marking all as ungrouped.
# Frame 161: Optimal k = 4, Inertia = 1257.03
# Frame 162: Optimal k = 3, Inertia = 1512.23
# Frame 163: Optimal k = 4, Inertia = 1461.17
# Frame 164: Optimal k = 3, Inertia = 2319.11
# Frame 165: Elbow point not found. Marking all as ungrouped.
# Frame 166: Elbow point not found. Marking all as ungrouped.
# Frame 167: Optimal k = 4, Inertia = 670.22
# Frame 168: Optimal k = 4, Inertia = 981.59
# Frame 169: Elbow point not found. Marking all as ungrouped.
# Frame 170: Optimal k = 3, Inertia = 654.49
# Frame 171: Optimal k = 3, Inertia = 772.53
# Frame 172: Optimal k = 4, Inertia = 592.97
# Frame 173: Optimal k = 4, Inertia = 679.27
# Frame 174: Optimal k = 3, Inertia = 1201.17
# Frame 175: Optimal k = 4, Inertia = 1073.46
# Frame 176: Optimal k = 3, Inertia = 755.89
# Frame 177: Elbow point not found. Marking all as ungrouped.
# Frame 178: Optimal k = 3, Inertia = 1697.93
# Frame 179: Elbow point not found. Marking all as ungrouped.
# Frame 180: Optimal k = 3, Inertia = 1970.89
# Frame 412: Optimal k = 4, Inertia = 1535.64
# Frame 413: Optimal k = 4, Inertia = 720.36
# Frame 414: Elbow point not found. Marking all as ungrouped.
# Frame 415: Elbow point not found. Marking all as ungrouped.
# Frame 416: Elbow point not found. Marking all as ungrouped.
# Frame 417: Optimal k = 4, Inertia = 961.81
# Frame 418: Optimal k = 4, Inertia = 753.47
# Frame 419: Optimal k = 4, Inertia = 1512.96
# Frame 420: Elbow point not found. Marking all as ungrouped.
# Frame 421: Optimal k = 3, Inertia = 1953.80
# Frame 422: Optimal k = 3, Inertia = 1582.86
# Frame 423: Elbow point not found. Marking all as ungrouped.
# Frame 424: Elbow point not found. Marking all as ungrouped.
# Frame 425: Elbow point not found. Marking all as ungrouped.
# Frame 426: Elbow point not found. Marking all as ungrouped.
# Frame 427: Optimal k = 3, Inertia = 2259.86
# Frame 428: Optimal k = 3, Inertia = 1959.18
# Frame 429: Optimal k = 4, Inertia = 974.12
# Frame 430: Optimal k = 4, Inertia = 898.49
# Frame 431: Optimal k = 3, Inertia = 972.58
# Frame 432: Optimal k = 4, Inertia = 1158.07
# Frame 433: Optimal k = 4, Inertia = 1481.71
# Frame 434: Elbow point not found. Marking all as ungrouped.
# Frame 435: Optimal k = 3, Inertia = 794.71
# Frame 436: Optimal k = 4, Inertia = 547.41
# Frame 437: Elbow point not found. Marking all as ungrouped.
# Frame 438: Elbow point not found. Marking all as ungrouped.
# Frame 439: Elbow point not found. Marking all as ungrouped.
# Frame 440: Elbow point not found. Marking all as ungrouped.
# Frame 441: Optimal k = 3, Inertia = 1898.12
# Frame 442: Elbow point not found. Marking all as ungrouped.
# Frame 443: Optimal k = 3, Inertia = 2681.19
# Frame 444: Optimal k = 3, Inertia = 1746.66
# Frame 445: Optimal k = 4, Inertia = 1186.43
# Frame 446: Optimal k = 3, Inertia = 1339.52
# Frame 447: Optimal k = 4, Inertia = 1585.07
# Frame 448: Optimal k = 3, Inertia = 1213.19
# Frame 449: Optimal k = 4, Inertia = 658.24
# Frame 450: Optimal k = 4, Inertia = 1172.01
# Frame 451: Optimal k = 4, Inertia = 1417.78
# Frame 452: Elbow point not found. Marking all as ungrouped.
# Frame 453: Optimal k = 3, Inertia = 2424.26
# Frame 454: Optimal k = 4, Inertia = 1208.31
# Frame 455: Optimal k = 3, Inertia = 859.47
# Frame 456: Optimal k = 3, Inertia = 1462.42
# Frame 457: Optimal k = 4, Inertia = 710.01
# Frame 458: Elbow point not found. Marking all as ungrouped.
# Frame 459: Optimal k = 3, Inertia = 1419.96
# Frame 460: Elbow point not found. Marking all as ungrouped.
# Frame 461: Elbow point not found. Marking all as ungrouped.
# Frame 462: Elbow point not found. Marking all as ungrouped.
# Frame 463: Optimal k = 4, Inertia = 1169.76
# Frame 464: Optimal k = 4, Inertia = 677.09
# Frame 465: Optimal k = 4, Inertia = 1096.65
# Frame 466: Optimal k = 3, Inertia = 1858.79
# Frame 467: Elbow point not found. Marking all as ungrouped.
# Frame 468: Elbow point not found. Marking all as ungrouped.
# Frame 469: Elbow point not found. Marking all as ungrouped.
# Frame 470: Optimal k = 4, Inertia = 1161.92
# Frame 471: Elbow point not found. Marking all as ungrouped.
# Frame 472: Elbow point not found. Marking all as ungrouped.
# Frame 473: Elbow point not found. Marking all as ungrouped.
# Frame 474: Elbow point not found. Marking all as ungrouped.
# Frame 475: Elbow point not found. Marking all as ungrouped.
# Frame 476: Elbow point not found. Marking all as ungrouped.
# Frame 477: Elbow point not found. Marking all as ungrouped.
# Frame 478: Optimal k = 3, Inertia = 1154.73
# Frame 479: Elbow point not found. Marking all as ungrouped.
# Frame 480: Elbow point not found. Marking all as ungrouped.
# Frame 481: Optimal k = 4, Inertia = 1056.07
# Frame 482: Optimal k = 4, Inertia = 650.57
# Frame 483: Optimal k = 4, Inertia = 840.98
# Frame 484: Optimal k = 3, Inertia = 2340.46
# Frame 485: Optimal k = 3, Inertia = 1993.76
# Frame 486: Elbow point not found. Marking all as ungrouped.
# Frame 487: Elbow point not found. Marking all as ungrouped.
# Frame 488: Elbow point not found. Marking all as ungrouped.
# Frame 489: Optimal k = 3, Inertia = 750.30
# Frame 490: Elbow point not found. Marking all as ungrouped.
# Frame 491: Elbow point not found. Marking all as ungrouped.
# Frame 492: Elbow point not found. Marking all as ungrouped.
# Frame 493: Elbow point not found. Marking all as ungrouped.
# Frame 494: Elbow point not found. Marking all as ungrouped.
# Frame 495: Elbow point not found. Marking all as ungrouped.
# Frame 496: Elbow point not found. Marking all as ungrouped.
# Frame 497: Optimal k = 4, Inertia = 1440.82
# Frame 498: Optimal k = 3, Inertia = 2362.58
# Frame 499: Elbow point not found. Marking all as ungrouped.
# Frame 500: Optimal k = 4, Inertia = 1219.40
# Frame 501: Optimal k = 4, Inertia = 1482.55
# Frame 502: Optimal k = 3, Inertia = 2054.52
# Frame 503: Elbow point not found. Marking all as ungrouped.
# Frame 504: Optimal k = 4, Inertia = 1300.87
# Frame 505: Optimal k = 3, Inertia = 1885.13
# Frame 506: Optimal k = 3, Inertia = 1502.96
# Frame 507: Optimal k = 3, Inertia = 1458.62
# Frame 508: Optimal k = 3, Inertia = 1199.14
# Frame 509: Optimal k = 4, Inertia = 1294.83
# Frame 510: Elbow point not found. Marking all as ungrouped.
# Frame 511: Optimal k = 4, Inertia = 780.28
# Frame 512: Optimal k = 3, Inertia = 1141.11
# Frame 513: Optimal k = 3, Inertia = 1150.27
# Frame 514: Optimal k = 4, Inertia = 1774.44
# Frame 515: Elbow point not found. Marking all as ungrouped.
# Frame 516: Elbow point not found. Marking all as ungrouped.
# Frame 517: Elbow point not found. Marking all as ungrouped.
# Frame 518: Optimal k = 3, Inertia = 1269.24
# Frame 519: Optimal k = 4, Inertia = 1544.02
# Frame 520: Elbow point not found. Marking all as ungrouped.
# Frame 521: Optimal k = 4, Inertia = 428.46
# Frame 522: Optimal k = 4, Inertia = 1082.11
# Frame 523: Optimal k = 4, Inertia = 1545.81
# Frame 524: Optimal k = 3, Inertia = 2104.94
# Frame 525: Optimal k = 4, Inertia = 1475.23
# Frame 526: Optimal k = 4, Inertia = 1225.06
# Frame 527: Optimal k = 4, Inertia = 1080.37
# Frame 528: Optimal k = 3, Inertia = 2303.59
# Frame 529: Elbow point not found. Marking all as ungrouped.
# Frame 530: Optimal k = 4, Inertia = 1147.04
# Frame 531: Optimal k = 3, Inertia = 1686.94
# Frame 532: Optimal k = 3, Inertia = 1132.96
# Frame 533: Optimal k = 4, Inertia = 882.30
# Frame 534: Optimal k = 3, Inertia = 1849.87
# Frame 535: Optimal k = 3, Inertia = 1320.52
# Frame 536: Optimal k = 3, Inertia = 1250.35
# Frame 537: Optimal k = 3, Inertia = 1675.17
# Frame 538: Optimal k = 3, Inertia = 867.14
# Frame 539: Optimal k = 3, Inertia = 1612.64
# Frame 540: Optimal k = 4, Inertia = 1310.57
# Frame 541: Optimal k = 4, Inertia = 770.53
# Frame 542: Optimal k = 4, Inertia = 976.06
# Frame 543: Optimal k = 4, Inertia = 918.55
# Frame 544: Optimal k = 4, Inertia = 993.89
# Frame 545: Optimal k = 4, Inertia = 1042.35
# Frame 546: Optimal k = 3, Inertia = 1055.39
# Frame 547: Optimal k = 4, Inertia = 1044.96
# Frame 548: Optimal k = 4, Inertia = 1904.74
# Frame 549: Optimal k = 4, Inertia = 1239.33
# Frame 550: Optimal k = 3, Inertia = 936.17
# Frame 551: Optimal k = 4, Inertia = 1011.23
# Frame 552: Optimal k = 4, Inertia = 672.77
# Frame 553: Optimal k = 4, Inertia = 1320.41
# Frame 554: Optimal k = 3, Inertia = 1126.84
# Frame 555: Optimal k = 3, Inertia = 1987.99
# Frame 556: Optimal k = 4, Inertia = 718.42
# Frame 557: Optimal k = 4, Inertia = 782.86
# Frame 558: Optimal k = 4, Inertia = 1520.39
# Frame 559: Optimal k = 4, Inertia = 1094.67
# Frame 560: Optimal k = 4, Inertia = 866.11
# Frame 561: Elbow point not found. Marking all as ungrouped.
# Frame 562: Optimal k = 4, Inertia = 991.83
# Frame 563: Optimal k = 4, Inertia = 1071.90
# Frame 564: Optimal k = 4, Inertia = 1362.45
# Frame 565: Optimal k = 4, Inertia = 1322.25
# Frame 566: Optimal k = 4, Inertia = 888.44
# Frame 567: Optimal k = 4, Inertia = 1137.10
# Frame 568: Optimal k = 4, Inertia = 807.65
# Frame 569: Optimal k = 4, Inertia = 1017.53
# Frame 570: Elbow point not found. Marking all as ungrouped.
# Frame 571: Optimal k = 4, Inertia = 911.14
# Frame 572: Elbow point not found. Marking all as ungrouped.
# Frame 573: Optimal k = 4, Inertia = 665.48
# Frame 574: Optimal k = 3, Inertia = 1300.79
# Frame 575: Optimal k = 3, Inertia = 1257.34
# Frame 576: Optimal k = 4, Inertia = 436.00
# Frame 577: Optimal k = 4, Inertia = 785.80
# Detected 1483 groups across all frames.
#
# Step 4: Saving group detection results...
# Saved group detection results to /content/group_detections_hierarchical.txt
#
# Results Summary:
# Total detections: 14441
# Detections in groups: 10335 (71.6%)
# Ungrouped detections: 4106 (28.4%)

# %% [markdown]
# **Clustering Evaluation Script**

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score

def load_group_detections(file_path):

    # Load group detection results from a .txt file.
    col_names = ["frame", "id", "x_center", "y_center", "z_center",
                 "length", "width", "height", "heading", "score", "group"]
    df = pd.read_csv(file_path, header=None, names=col_names)
    df["group"] = df["group"].astype(int)
    print(f"Loaded {len(df)} detections from {file_path}.")
    return df

def compute_clustering_metrics(detections):

    # Compute silhouette, Davies-Bouldin, and Calinski-Harabasz scores per frame.

    silhouette_scores = []
    db_scores = []
    ch_scores = []

    for frame in detections["frame"].unique():
        frame_data = detections[detections["frame"] == frame]
        clustered_data = frame_data[frame_data["group"] != 0]

        if len(set(clustered_data["group"])) > 1:
            X = clustered_data[["x_center", "y_center", "z_center"]].to_numpy()
            labels = clustered_data["group"].to_numpy()

            try:
                sil_score = silhouette_score(X, labels)
                db_index = davies_bouldin_score(X, labels)
                ch_index = calinski_harabasz_score(X, labels)

                silhouette_scores.append(sil_score)
                db_scores.append(db_index)
                ch_scores.append(ch_index)
            except Exception as e:
                print(f"Skipping frame {frame} due to error: {e}")

    return {
        "silhouette_score": np.mean(silhouette_scores) if silhouette_scores else None,
        "davies_bouldin_index": np.mean(db_scores) if db_scores else None,
        "calinski_harabasz_index": np.mean(ch_scores) if ch_scores else None
    }

def evaluate_clustering(file_path, method_name):

    # Evaluate and print clustering performance given a file path and method name.
    detections = load_group_detections(file_path)
    metrics = compute_clustering_metrics(detections)

    print(f"\n===== {method_name} Clustering Evaluation =====")
    if metrics["silhouette_score"] is not None:
        print(f"Silhouette Score: {metrics['silhouette_score']:.3f} (Higher is better)")
    else:
        print("Silhouette Score: Not available")

    if metrics["davies_bouldin_index"] is not None:
        print(f"Davies-Bouldin Index: {metrics['davies_bouldin_index']:.3f} (Lower is better)")
    else:
        print("Davies-Bouldin Index: Not available")

    if metrics["calinski_harabasz_index"] is not None:
        print(f"Calinski-Harabasz Index: {metrics['calinski_harabasz_index']:.3f} (Higher is better)")
    else:
        print("Calinski-Harabasz Index: Not available")

# %%
# Call for all methods
evaluate_clustering("/content/group_detections.txt", "DBSCAN-Based")
evaluate_clustering("/content/group_detections_elbow.txt", "KMeans-Based")
evaluate_clustering("/content/group_detections_hierarchical.txt", "Hierarchical Agglomerative")
# Out:
# Loaded 14441 detections from /content/group_detections.txt.
#
# ===== DBSCAN-Based Clustering Evaluation =====
# Silhouette Score: 0.814 (Higher is better)
# Davies-Bouldin Index: 0.193 (Lower is better)
# Calinski-Harabasz Index: 521.517 (Higher is better)
# Loaded 14441 detections from /content/group_detections_elbow.txt.
#
# ===== KMeans-Based Clustering Evaluation =====
# Silhouette Score: 0.505 (Higher is better)
# Davies-Bouldin Index: 0.624 (Lower is better)
# Calinski-Harabasz Index: 35.680 (Higher is better)
# Loaded 14441 detections from /content/group_detections_hierarchical.txt.
#
# ===== Hierarchical Agglomerative Clustering Evaluation =====
# Silhouette Score: 0.519 (Higher is better)
# Davies-Bouldin Index: 0.595 (Lower is better)
# Calinski-Harabasz Index: 36.194 (Higher is better)
